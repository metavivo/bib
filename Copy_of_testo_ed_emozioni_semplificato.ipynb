# %% [markdown]
# <a href="https://colab.research.google.com/github/metavivo/bib/blob/master/Copy_of_testo_ed_emozioni_semplificato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Carica

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import RegexpTokenizer
from google.colab import drive
import csv


global word_tokenizer
global data_path
global data_filename
global data
global emotion_tags


def car(inlist):
    if inlist == []:
        return inlist
    else:
        return inlist[0]

def cdr(inlist):
    if inlist == []:
        return inlist
    else:
        return inlist[1:len(inlist)]

def cons(el, inlist):
    outlist = append([], inlist)
    outlist.insert(0, el)
    return outlist

def list(el):
    return cons(el, [])

def append(list1, list2):
    outlist = []
    for el in list1:
        outlist.append(el)
    for el in list2:
        outlist.append(el)
    return outlist

def filter(op, inlist):
    l = inlist
    accum = []
    if inlist == []:
        return inlist
    else:
        while len(l) > 0:
            if op(l[0]):
                accum = append(accum, list(car(l)))
            l = cdr(l)
    return accum

def load_data():
    return load_data1(data_filename)

def load_data1(data_filename):
    with open(data_filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=';')
        out = {}
        for line in csv_reader:
            if line[0] != 'NO TRANSLATION' and line[0] != '\ufeffItalian (it)':
                out[line[0]] = [int(x) for x in line[1:]]
        return out

def word_to_info(word):
    return word_to_info1(word, data)

def word_to_info1(word, data):
    if word in data:
        return data[word]

def word_to_emotions(word):
    info = word_to_info(word)
    if info != None:
        emo_info_list = info[2:]
        emo_tag_list = emotion_tags[2:]
        i = 0
        pairs = []
        while i < 8:
            pairs = pairs + [[emo_tag_list[i], emo_info_list[i]]]
            i = i + 1
        filtered_pairs = filter(lambda x: x[1] == 1, pairs)
        out = [x[0] for x in filtered_pairs]
        if out != []:
            return out

def text_to_emotions_info(input_text):
    step1 = word_tokenizer.tokenize(input_text)
    step2 = [[x, word_to_emotions(x)] for x in step1]
    step3 = filter(lambda x: None != x[1], step2)
    return step3

def get_emotion_text(text):
  step1 = text_to_emotions_info(text)
  step2 = [x[1] for x in step1]
  step3 = [' '.join(x) for x in step2]
  step4 = ' '.join(step3)
  return step4

def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

import shutil
shutil.rmtree('/content/datasetAndLibraryToInstall', ignore_errors=True)

# !git clone https://github.com/matte156/datasetAndLibraryToInstall.git

data_path = '/content/datasetAndLibraryToInstall/step3 - prime emozioni e polarità/'

data_filename = data_path + 'ita_emo.csv'

data = load_data()

word_tokenizer = RegexpTokenizer('\w+')

emotion_tags = ['Positive', 'Negative', 'rabbia', 'speranza', 'disgusto', 
                'paura', 'gioia', 'tristezza', 'sorpresa', 'fiducia']
# Out:
# Cloning into 'datasetAndLibraryToInstall'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (19/19), done.

# %% [markdown]
# ## Esegui

# %%
text = "Recovery, sulla giustizia Draghi parte dalle riforme di Bonafede (ma le annacqua). Road map: a giugno la legge su Csm e autunno di fuoco con processo civile e penale Recovery, sulla giustizia Draghi parte dalle riforme di Bonafede (ma le annacqua). Road map: a giugno la legge su Csm e autunno di fuoco con processo civile e penale Nella versione definitiva del Pnrr l'esecutivo sceglie di non decidere, almeno sui punti pi\xF9 delicati delle leggi che dovranno essere approvate nei prossimi mesi. Dalla riforma del Csm sparisce il tema delle porte girevoli tra consiglieri e parlamentari; in materia di prescrizione si prevedono \"eventuali iniziative\" da inserire in una cornice \"razionalizzata e pi\xF9 efficiente\" dei processi; sul secondo grado di giudizio non c'\xE8 pi\xF9 la proposta di istituire un \"giudice monocratico d'appello\". Ma senza un accordo, avverte Cartabia, \"l'Italia perder\xE0 i fondi europei\"  di Marco Procopio | 26 APRILE 2021 Approfondito quanto basta per ottemperare alle richieste dell\u2019Unione europea, sufficientemente generico per non irritare le diverse anime della (larghissima) maggioranza di governo. In materia di giustizia il Recovery plan targato Mario Draghi sceglie di non decidere, almeno sui punti pi\xF9 delicati delle riforme che dovranno essere approvate nei prossimi mesi. La versione finale del testo, licenziato sabato notte in Consiglio dei ministri, fa proprie gran parte delle misure elaborate dall\u2019ex ministro Alfonso Bonafede e inserite nel Piano precedente, dall\u2019accelerazione dei processi all\u2019abbattimento degli arretrati grazie a oltre 20mila nuove assunzioni, ma annacqua una serie di provvedimenti considerati centrali dal governo Conte. Dalla riforma del Consiglio superiore della magistratura sparisce il tema delle porte girevoli tra consiglieri ed ex membri del governo o del Parlamento; in materia di prescrizione si parla di adottare \u201Ceventuali iniziative\u201D da inserire in una cornice \u201Crazionalizzata e pi\xF9 efficiente\u201D dei processi; sul secondo grado di giudizio \u2013 il pi\xF9 problematico in termini di durata \u2013 non c\u2019\xE8 pi\xF9 la proposta di istituire un \u201Cgiudice monocratico d\u2019appello\u201D per snellire le procedure.  Il risultato \xE8 uno schema di riforme che sposta solo un po\u2019 pi\xF9 in l\xE0 la discussione politica: la road map chiesta da Bruxelles \xE8 infatti serratissima. Il primo scoglio che la ministra della Giustizia Marta Cartabia dovr\xE0 superare \xE8 la revisione dell\u2019ordinamento giudiziario, in cui rientra anche la riorganizzazione del Csm. Il governo, come si legge nel Pnrr, ha \u201Crichiesto la trattazione prioritaria che ne comporter\xE0 la calendarizzazione per l\u2019esame dell\u2019Aula entro giugno 2021\u201C. Ma il vero banco di prova sar\xE0 a settembre, quando \xE8 prevista l\u2019approvazione delle leggi delega sulla riforma del processo penale, del processo civile e dei procedimenti speciali (nel giro di un anno arriveranno i decreti attuativi, mentre per la giustizia tributaria si dovr\xE0 aspettare il 2022). Un vero e proprio autunno caldo in cui Lega, Forza Italia, Pd, Leu e Movimento 5 stelle saranno costretti a trovare un accordo sulla revisione dell\u2019intero sistema giudiziario italiano. Non \xE8 un caso che nelle scorse ore la stessa guardasigilli abbia fatto un appello all\u2019unit\xE0, ricordando in un\u2019intervista a La Stampa che se questa missione dovesse fallire \u201Cl\u2019Italia non avr\xE0 i fondi europei\u201C. Non solo i circa 3 miliardi stanziati per la giustizia, ma l\u2019intero pacchetto da 191 miliardi in arrivo dall\u2019Ue per risollevare il Paese dopo la pandemia." #@param {type:"string"}

emotion_text = get_emotion_text(text)

wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(emotion_text)
plot_cloud(wordcloud)
